# %%
import matplotlib as mtp
import matplotlib.pyplot as plt
import numpy as np
x=np.linspace(0,5,11)
print(x)
y=x**2
plt.plot(x,y,'r-')
plt.xlabel('Emp_Exp')
plt.ylabel('Salaries')
plt.title('Financial Growth')
plt.show()
# Out:
# [0.  0.5 1.  1.5 2.  2.5 3.  3.5 4.  4.5 5. ]

# %%
#histogram  -  graph showing frequency distributions.
import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(170, 10, 250)
print(x)
plt.hist(x)
plt.show()
# Out:
# [169.31071176 145.60731063 169.81435143 178.54744844 153.25249757
#  180.63501486 193.32390411 195.73153907 168.90445119 168.54193999
#  184.39108993 160.19117687 180.20409463 194.88270626 158.80404026
#  152.69406307 170.85408322 157.40459225 161.56232329 180.15465881
#  180.52888119 173.11429489 164.36119002 171.61611821 167.49772925
#  158.75304542 192.45771095 174.66721557 171.21478552 198.7502564
#  156.97769825 184.28677789 149.01984736 168.4424062  159.26241202
#  182.08325783 176.93489091 170.33043922 163.26410418 162.94574263
#  172.66365101 166.65327124 179.37804558 169.61277357 152.55853395
#  152.39554517 161.84823341 182.64462114 168.38543414 175.84770322
#  163.23154171 175.16164817 167.21751952 173.91593967 158.18952473
#  168.96532265 179.73095015 168.34574619 173.713133   171.49383496
#  159.57230901 168.5888719  162.5832783  182.99493426 168.5167054
#  146.92346947 175.99470929 174.72235008 169.62126795 172.66485514
# ...

# %%
# df['w'] - to get a column in df
# df.loc['a'] - for row in df
# xticks,yticks

# %%
import pandas as pd
from numpy.random import randn

df=pd.DataFrame(randn(5,4),['a','b','c','d','e'],['w','x','y','z'])
df
# Out:
#           w         x         y         z
# a -1.259805 -0.507372 -1.941030  0.198001
# b  1.355846 -0.566626 -0.819138 -1.528957
# c  0.312986 -0.303113 -1.849213  2.891263
# d  0.741086 -1.239732  1.801142  0.913982
# e  0.459171 -0.191667  0.810621 -0.960708

# %%
df['w'].hist()
# Out:
# <Axes: >

# %%
#bar plot
df.plot.bar()
plt.show()

# %%
#Based on client req->u can choose plots
#Area plot ->should not have neg values in df
df.plot.Area()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 3
#       1 #Based on client req->u can choose plots
#       2 #Area plot ->should not have neg values in df
# ----> 3 df.plot.Area()
#
# AttributeError: 'PlotAccessor' object has no attribute 'Area'

# %% [markdown]
# Plotting in pandas provides a basic framework for visualizing our data,
# but as you'll see we will sometimes need to also use features from Matplotlib to enhance our plots.
# In particular, we will use features from the the pyplot module in Matplotlib,
# which provides MATLAB-like plotting.

# %%
#scatter plot
df.plot.scatter(x=df['w'],y=df['x'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 2
#       1 #scatter plot
# ----> 2 df.plot.scatter(x=df['w'],y=df['x'])
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/plotting/_core.py:1697, in PlotAccessor.scatter(self, x, y, s, c, **kwargs)
#    1614 def scatter(self, x, y, s=None, c=None, **kwargs) -> PlotAccessor:
#    1615     """
#    1616     Create a scatter plot with varying marker point size and color.
#    1617
#    (...)
#    1695         ...                       colormap='viridis')
#    1696     """
# -> 1697     return self(kind="scatter", x=x, y=y, s=s, c=c, **kwargs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/plotting/_core.py:945, in PlotAccessor.__call__(self, *args, **kwargs)
#     943 if kind in self._dataframe_kinds:
#     944     if isinstance(data, ABCDataFrame):
# ...

# %%
#box plt
df.plot.box()
# Out:
# <Axes: >

# %%
#seaborn,plotly-3D usecases,Bokeh-for web design based applications,

# %%
#bI Analyst
#deploy-

# %%
DS Life cycle:
    DAta Acquisition,Data-preprocessing,ML algo,Pattern Evaluation,KNowledge representation

# %%
#Applications -> Healthcare,gaming,Image recognition,Recommendation systems,LOgistics-to optimize routes to ensure faster delivery
Airline route planning,Augmented reality

# %%
#MAthematics- > statistics,Linear algebra,probaility,Matrices,Baysian theorem

# %%
#statistics lib

# %%
#ETL ->Data Wrangling ->EDA(alayzing data after ETL)-descriptive statistics
#Domain knowledge
#skewness?
#best ETL tools-Apache.io,hadoop,..many are there

# %%
#pre-processing
1)Empty cells/missing values
2)Data in wrong format
3)Wrong data
4)Duplicates

# %%
#Datasets
1)Internal import ->sklearn,seaborn
2)External datasets
 kaggle,UCI machine learning repo,other

# %%
import pandas as pd
df=pd.read_csv("/home/labuser/Downloads/data.csv")
df_old=pd.read_csv("/home/labuser/Downloads/data.csv")
df_old
#print(df.to_string())  #to print entire dataset
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
df.isna().sum()
# Out:
# Duration    0
# Pulse       0
# Maxpulse    0
# Calories    5
# dtype: int64

# %%
print(df.head())
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 5.4 KB
# None

# %%
print(df.tail())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4

# %%
#drop null values
new_df=df.dropna()
print(new_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 164 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  164 non-null    int64
#  1   Pulse     164 non-null    int64
#  2   Maxpulse  164 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 6.4 KB
# None

# %%
#replace empty values with fillna
df.fillna(130,inplace=True)
#only for specified columns fill values

# %%
#task-clean date data

# %%
#print(df.to_string())

# %%
#date in wrong format
for x in df.index:
  if df.loc[x, "Duration"] > 120:
    df.loc[x, "Duration"] = 120

# %%
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
#duplicates
df.drop_duplicates(inplace = True)
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [162 rows x 4 columns]

# %% [markdown]
# Use Regex to Match and Parse Dates
# The Python re module can be used to match and parse dates in different formats. Write regex patterns to identify dates like:
#     import re
#
# date_regex = r"\d{2}[-./]\d{2}[-./]\d{4}" # match common date formats
# Extract date strings from the dataset and use re.match to test if they match expected formats.
# standard ISO 8601 format "YYYY-MM-DD"
# from datetime import datetime
#
# standardized_date = datetime.strptime(date_string, "%m/%d/%Y").isoformat()

# %% [markdown]
# Python strptime()
# The strptime() method creates a datetime object from the given string.
#
# Note: You cannot create datetime object from every string. The string needs to be in a certain format.
#
# Example 1: string to datetime object
#
# from datetime import datetime
#
# date_string = "21 June, 2018"
#
# print("date_string =", date_string)
# print("type of date_string =", type(date_string))
#
# date_object = datetime.strptime(date_string, "%d %B, %Y")
#
# print("date_object =", date_object)
# print("type of date_object =", type(date_object))
# When you run the program, the output will be:
#
#
# date_string = 21 June, 2018
# type of date_string = <class 'str'>
# date_object = 2018-06-21 00:00:00
# type of date_object = <class 'datetime.datetime'>
